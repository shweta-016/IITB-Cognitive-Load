# %%
import pandas as pd

# Load files
eeg = pd.read_csv("C:/Users/Admin/Desktop/cognitive load/Data/EEG.csv")
gsr = pd.read_csv("C:/Users/Admin/Desktop/cognitive load/Data/GSR.csv")
psy = pd.read_csv("C:/Users/Admin/Desktop/cognitive load/Data/PSY.csv")

# Convert timestamp column
eeg['TimeStamp'] = pd.to_datetime(eeg['TimeStamp'])
gsr['TimeStamp'] = pd.to_datetime(gsr['TimeStamp'])
psy['TimeStamp'] = pd.to_datetime(psy['TimeStamp'])

# Sort data
eeg = eeg.sort_values('TimeStamp')
gsr = gsr.sort_values('TimeStamp')

print("EEG shape:", eeg.shape)
print("GSR shape:", gsr.shape)
print("PSY shape:", psy.shape)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1528\951493492.py:4: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   eeg = pd.read_csv("C:/Users/Admin/Desktop/cognitive load/Data/EEG.csv")
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1528\951493492.py:6: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   psy = pd.read_csv("C:/Users/Admin/Desktop/cognitive load/Data/PSY.csv")
# EEG shape: (526689, 32)
# GSR shape: (526689, 5)
# PSY shape: (526689, 6)
